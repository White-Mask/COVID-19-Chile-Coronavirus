# %%
#Instalamos geopandas
pip install geopandas

# %%
#Instalamos mapclassify
pip install mapclassify

# %%
#Librerías varias
import os
import datetime
import pandas as pd
from datetime import date
from google.colab import drive

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/COVID-19 Chile (Coronavirus)/Database (CSV)') #Carpeta donde tenemos guardados los datasets (csv)

# %% [markdown]
# #Cargamos el primer dataset
# El primer dataset contiene:
# * Número total de contagiados con COVID-19 a la fecha
# * Número de nuevos contagiados
# * Número de recuperados a la fecha
# * Número de fallecidos a la fecha

# %%
fq = pd.read_csv('Resumen_COVID-19_Chile_.csv')
fq
# Out:
#     recuperados a nivel nacional  ...       Fecha
# 0                              0  ...  2020-03-03
# 1                              0  ...  2020-03-04
# 2                              0  ...  2020-03-05
# 3                              0  ...  2020-03-06
# 4                              0  ...  2020-03-07
# 5                              0  ...  2020-03-08
# 6                              0  ...  2020-03-09
# 7                              0  ...  2020-03-10
# 8                              0  ...  2020-03-11
# 9                              0  ...  2020-03-12
# 10                             0  ...  2020-03-13
# 11                             0  ...  2020-03-14
# 12                             0  ...  2020-03-15
# 13                             0  ...  2020-03-16
# 14                             0  ...  2020-03-17
# 15                             0  ...  2020-03-18
# 16                             5  ...  2020-03-19
# 17                             6  ...  2020-03-20
# 18                             8  ...  2020-03-21
# 19                             8  ...  2020-03-22
# 20                            11  ...  2020-03-23
# 21                            17  ...  2020-03-24
# 22                            22  ...  2020-03-25
# 23                            33  ...  2020-03-26
# 24                            43  ...  2020-03-27
# 25                            61  ...  2020-03-28
# 26                            75  ...  2020-03-29
# 27                           156  ...  2020-03-30
# 28                           156  ...  2020-03-31
# 29                           234  ...  2020-04-01
# 30                           335  ...  2020-04-02
# 31                           427  ...  2020-04-03
#
# [32 rows x 5 columns]

# %% [markdown]
# #Análisis de los datos
#
# Este primer grafico nos muestra los casos de personas que tienen el COVID-19 acumulados en tiempo.

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(13,13)

ay = fq.plot('Fecha','Casos_totales_nuevos',label='Casos totales por dia')
plt.title("Casos totales por dia de personas con COVID-19 en Chile")
plt.xlabel("Fecha")
plt.ylabel("Casos totales")
mapeado = range(len(fq.Casos_totales_nuevos))
plt.xticks(mapeado,fq.Fecha,rotation='vertical')
plt.margins(0.02)

for i, v in enumerate(fq['Casos_totales_nuevos']):
  ay.annotate(v, xy=(i, v))
  
plt.show()

# %% [markdown]
# Hacemos los cálculos de casos recuperados y fallecidos diarios antes de hacer el grafico.

# %%
#Calculamos los casos diarios de recuperados
C_recuperado_dia = []
count = 0
for i in fq['recuperados a nivel nacional']:
  if i == 0:
    C_recuperado_dia.append(0)
    count+=1
  else:
    C_recuperado_dia.append(int(i - fq.iloc[count-1:count,:1].values))
    count+=1
#print(C_recuperado_dia)

#Calculamos los casos de fallecidos diarios
C_fellecidos_dia = []
count = 0
for k in fq['Casos_fallecidos']:
  if k == 0:
    C_fellecidos_dia.append(0)
    count+=1
  else:
    C_fellecidos_dia.append(int(k - fq.iloc[count-1:count,1:2].values))
    count+=1
#print(C_fellecidos_dia)

# %% [markdown]
# Este grafico muestra casos nuevos de personas infectadas, los recuperados y fallecidos por día.

# %%
import numpy as np

fech = fq['Fecha']
plt.bar(fech,fq.Casos_totales_dia,color='blue',label = 'Casos nuevos')
#plt.bar(fech,fq['recuperados a nivel nacional'], color = 'green',label ='Recuperados')
plt.bar(fech,C_recuperado_dia, color = 'green',label ='Recuperados')
plt.bar(fech,C_fellecidos_dia, color = 'red',label = 'Fallecidos')


plt.title("Casos nuevos por dia de COVID-19 en Chile")
plt.xlabel("Fecha")
plt.ylabel("Casos nuevos")
mapeado2 = range(len(fq.Casos_totales_dia))
plt.xticks(mapeado2,fq.Fecha,rotation='vertical')
plt.yticks(np.arange(0,400,step=10))
plt.legend(loc = 'upper left')
plt.tight_layout()
plt.grid(True)
plt.margins(0.02)
plt.show()

# %% [markdown]
# #Cargamos el segundo dataset
# El segundo dataset contiene:
# * Número casos nuevos
# * Número casos totales a la fecha
# * Número de fallecidos
#
# y todos estos ordenados por región

# %%
df = pd.read_csv('Casos_COVID-19_Chile_'+str(date.today())+'.csv')
df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row0_col1 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row0_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row1_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row1_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row1_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row2_col1 {
#             background-color:  #ffece3;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row2_col2 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row2_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row3_col1 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row3_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row4_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row4_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row4_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row5_col1 {
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row5_col2 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row5_col4 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row6_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row6_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row6_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row7_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row7_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row7_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row8_col1 {
#             background-color:  #ffece3;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row8_col2 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row8_col4 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row9_col1 {
#             background-color:  #fcb69b;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row9_col2 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row9_col4 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row10_col1 {
#             background-color:  #fcbca2;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row10_col2 {
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row10_col4 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row11_col1 {
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row11_col2 {
#             background-color:  #fcbda4;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row11_col4 {
#             background-color:  #a30f15;
#             color:  #f1f1f1;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row12_col1 {
#             background-color:  #fee7dc;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row12_col2 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row12_col4 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row13_col1 {
#             background-color:  #fcaf93;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row13_col2 {
#             background-color:  #fedfd0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row13_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row14_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row14_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row14_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row15_col1 {
#             background-color:  #fc8e6e;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row15_col2 {
#             background-color:  #fee7db;
#             color:  #000000;
#         }    #T_21bf58fa_75bf_11ea_9821_0242ac1c0002row15_col4 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }</style><table id="T_21bf58fa_75bf_11ea_9821_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Región</th>        <th class="col_heading level0 col1" >Casos nuevos</th>        <th class="col_heading level0 col2" >Casos totales</th>        <th class="col_heading level0 col3" >% Casos totales**</th>        <th class="col_heading level0 col4" >Fallecidos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21bf58fa_75bf_11ea_9821_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_21bf58fa_75bf_11ea_9821_0242ac1c0002row0_col0" class="data row0 col0" >Arica y Parinacota</td>
#                         <td id="T_21bf58fa_75bf_11ea_9821_0242ac1c0002row0_col1" class="data row0 col1" >5</td>
#                         <td id="T_21bf58fa_75bf_11ea_9821_0242ac1c0002row0_col2" class="data row0 col2" >12</td>
#                         <td id="T_21bf58fa_75bf_11ea_9821_0242ac1c0002row0_col3" class="data row0 col3" >0 %</td>
#                         <td id="T_21bf58fa_75bf_11ea_9821_0242ac1c0002row0_col4" class="data row0 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_21bf58fa_75bf_11ea_9821_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_21bf58fa_75bf_11ea_9821_0242ac1c0002row1_col0" class="data row1 col0" >Tarapacá</td>
#                         <td id="T_21bf58fa_75bf_11ea_9821_0242ac1c0002row1_col1" class="data row1 col1" >1</td>

# %% [markdown]
# #Análisis de los datos del segundo dataset
# En este grafico se muestra los nuevos casos de COVID-19 del dia actual por region.

# %%
df.plot.barh('Región','Casos nuevos')
plt.title("N° de casos nuevos por dia de COVID-19 por región "+str(date.today()))
plt.xlabel('N° de nuevos contagiados')
plt.ylabel('Regiones')
plt.show()

# %% [markdown]
# Cargamos el archivo Geojson que contiene el mapa de chile.

# %%
import geopandas as gpd

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/COVID-19 Chile (Coronavirus)/Map')

map_data = gpd.read_file('Mapa_Chile_Regiones.geojson')
map_data.head()

mapa = map_data.iloc[:,1:2]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# En este grafico se muestra la concentración de infectados por región.

# %%
fig, ax = plt.subplots(figsize=(15, 17))

ax.set_title('Contagiados por región al '+str(date.today()), 
             pad = 20, 
             fontdict={'fontsize':20, 'color': '#000000'})

ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')

casosxregion = df.iloc[:16,2:3]

map_data = map_data.assign(casos= casosxregion)
map_data.plot(column='casos', cmap='OrRd', ax=ax, legend=True, zorder=5,scheme='quantiles',legend_kwds={'loc': 'upper left'})

# %% [markdown]
# En este se muestra los casos totales por número de día.
#
# Lo que hacemos aquí es una regresión polinomial que se ajusta a los datos entregados por el minal para tener una idea visual de cómo se comportan.

# %%
dia_actual = len(fq) + 1
dias = np.arange(1,dia_actual)
X = dias.reshape(len(dias),1)
#y = fq.iloc[:,2:3]
y = fq.Casos_totales_nuevos

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

poly_regression = PolynomialFeatures(degree=4)
X_poly_regression = poly_regression.fit_transform(X)

lin_regression_2 = LinearRegression()
lin_regression_2.fit(X_poly_regression,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Hacemos la exponencial.

# %%
from scipy.optimize import curve_fit

def exponential_model(t, a, b):
    return a*np.exp(b*t)

ini = [1.0,1.0]
datax = list(dias)
datay = list(y)
popt,pcov = curve_fit(exponential_model, datax, datay,ini)
xfit = np.arange(1.0,33.0,0.1)

# %% [markdown]
# ##Mostramos el grafico con los datos entregados por el minsal, la regresión polinomial y la exponencial.
# ###OJO
# **En las últimas mediciones entregadas por el minal, los puntos (los datos) no coinciden con la exponencial, esto no significa que se esté “aplanando” la curva, lo que pasa es que no todos los días se hace la misma cantidad de test, por lo que podríamos inferir que quizás no se hace la cantidad de test suficiente.**

# %%
X_grid = np.arange(1,dia_actual,0.1)
X_grid = X_grid.reshape(len(X_grid),1)

plt.scatter(X,y,color='red',label='Casos por minsal')
plt.plot(X_grid,lin_regression_2.predict(poly_regression.fit_transform(X_grid)),color='blue',label='Polynomial model')
plt.plot(xfit,exponential_model(xfit,*popt),color='orange',label = 'Exponential Model')

plt.title('N° de casos totales con COVID-19 por día')
plt.xlabel('N° del día')
plt.ylabel('N° del casos totales')

plt.legend(loc = 'upper left')

plt.show()

# %% [markdown]
# Aquí hacemos una predicción para los próximos 2 días con la pendiente de la regresión polinomial.

# %%
for i in range(len(fq),len(fq)+3):
  prediccion = int(lin_regression_2.predict(poly_regression.fit_transform([[i]])))
  print('Dia '+str(i)+': '+str(prediccion)+' infectados aprox.')
# Out:
# Dia 32: 3770 infectados aprox.
# Dia 33: 4162 infectados aprox.
# Dia 34: 4572 infectados aprox.
