# %%
#Instalamos geopandas
pip install geopandas

# %%
#Librerías varias
import os
import datetime
import pandas as pd
from datetime import date
from google.colab import drive

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/COVID-19 Chile (Coronavirus)/Database (CSV)') #Carpeta donde tenemos guardados los datasets (csv)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Cargamos el primer dataset
# El primer dataset contiene:
# * Número total de contagiados con COVID-19 a la fecha
# * Número de nuevos contagiados
# * Número de recuperados a la fecha
# * Número de fallecidos a la fecha

# %%
fq = pd.read_csv('Resumen_COVID-19_Chile_.csv')
fq
# Out:
#     recuperados a nivel nacional  ...       Fecha
# 0                              0  ...  2020-03-03
# 1                              0  ...  2020-03-04
# 2                              0  ...  2020-03-05
# 3                              0  ...  2020-03-06
# 4                              0  ...  2020-03-07
# 5                              0  ...  2020-03-08
# 6                              0  ...  2020-03-09
# 7                              0  ...  2020-03-10
# 8                              0  ...  2020-03-11
# 9                              0  ...  2020-03-12
# 10                             0  ...  2020-03-13
# 11                             0  ...  2020-03-14
# 12                             0  ...  2020-03-15
# 13                             0  ...  2020-03-16
# 14                             0  ...  2020-03-17
# 15                             0  ...  2020-03-18
# 16                             5  ...  2020-03-19
# 17                             6  ...  2020-03-20
# 18                             8  ...  2020-03-21
# 19                             8  ...  2020-03-22
# 20                            11  ...  2020-03-23
# 21                            17  ...  2020-03-24
# 22                            22  ...  2020-03-25
# 23                            33  ...  2020-03-26
# 24                            43  ...  2020-03-27
# 25                            61  ...  2020-03-28
# 26                            75  ...  2020-03-29
# 27                           156  ...  2020-03-30
# 28                           156  ...  2020-03-31
#
# [29 rows x 5 columns]

# %% [markdown]
# #Análisis de los datos
#
# Este primer grafico nos muestra los casos de personas que tienen el COVID-19 acumulados en tiempo.

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(15,15)

ay = fq.plot('Fecha','Casos_totales_nuevos',label='Casos totales por dia')
plt.title("Casos totales por dia de personas con COVID-19 en Chile")
plt.xlabel("Fecha")
plt.ylabel("Casos totales")
mapeado = range(len(fq.Casos_totales_nuevos))
plt.xticks(mapeado,fq.Fecha,rotation='vertical')
plt.margins(0.25)

for i, v in enumerate(fq['Casos_totales_nuevos']):
  ay.annotate(v, xy=(i, v))
  
plt.show()

# %% [markdown]
# Este grafico muestra casos nuevos de personas infectadas, los recuperados y fallecidos por día.

# %%
import numpy as np

fech = fq['Fecha']
plt.bar(fech,fq.Casos_totales_dia,color='blue',label = 'Casos nuevos')
plt.bar(fech,fq['recuperados a nivel nacional'], color = 'green',label ='Recuperados')
plt.bar(fech,fq.Casos_fallecidos, color = 'red',label = 'Fallecidos')


plt.title("Casos nuevos por dia de COVID-19 en Chile")
plt.xlabel("Fecha")
plt.ylabel("Casos nuevos")
mapeado2 = range(len(fq.Casos_totales_dia))
plt.xticks(mapeado2,fq.Fecha,rotation='vertical')
plt.yticks(np.arange(0,300,step=10))
plt.legend(loc = 'upper left')
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# #Cargamos el segundo dataset
# El segundo dataset contiene:
# * Número casos nuevos
# * Número casos totales a la fecha
# * Número de fallecidos
#
# y todos estos ordenados por región

# %%
df = pd.read_csv('Casos_COVID-19_Chile_'+str(date.today())+'.csv')
df.iloc[6:7,2:3]*=1000 #Esta fila nos da problas porque el 1000 lo interpreta como 1.0
df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row0_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row1_col1 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row1_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row1_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row2_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row2_col2 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row2_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row3_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row3_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row3_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row4_col1 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row4_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row4_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row5_col1 {
#             background-color:  #ffece3;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row5_col2 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row5_col4 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row6_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row6_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row6_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row7_col1 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row7_col2 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row7_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row8_col1 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row8_col2 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row8_col4 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row9_col1 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row9_col2 {
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row9_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row10_col1 {
#             background-color:  #fee1d4;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row10_col2 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row10_col4 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row11_col1 {
#             background-color:  #fb7d5d;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row11_col2 {
#             background-color:  #fdc6b0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row11_col4 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row12_col1 {
#             background-color:  #fee7db;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row12_col2 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row12_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row13_col1 {
#             background-color:  #fdcebb;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row13_col2 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row13_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row14_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row14_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row14_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row15_col1 {
#             background-color:  #fdccb8;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row15_col2 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row15_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_7d6f7566_7364_11ea_a7b9_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Región</th>        <th class="col_heading level0 col1" >Casos nuevos</th>        <th class="col_heading level0 col2" >Casos totales</th>        <th class="col_heading level0 col3" >% Casos totales**</th>        <th class="col_heading level0 col4" >Fallecidos</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7d6f7566_7364_11ea_a7b9_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row0_col0" class="data row0 col0" >Arica y Parinacota</td>
#                         <td id="T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row0_col2" class="data row0 col2" >6</td>
#                         <td id="T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row0_col3" class="data row0 col3" >0 %</td>
#                         <td id="T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row0_col4" class="data row0 col4" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7d6f7566_7364_11ea_a7b9_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row1_col0" class="data row1 col0" >Tarapacá</td>
#                         <td id="T_7d6f7566_7364_11ea_a7b9_0242ac1c0002row1_col1" class="data row1 col1" >2</td>

# %% [markdown]
# #Análisis de los datos del segundo dataset
# En este grafico se muestra los nuevos casos de COVID-19 del dia actual por region.

# %%
df.plot.barh('Región','Casos nuevos')
plt.title("N° de casos nuevos por dia de COVID-19 por región "+str(date.today()))
plt.xlabel('N° de nuevos contagiados')
plt.ylabel('Regiones')
plt.show()

# %% [markdown]
# Cargamos el archivo Geojson que contiene el mapa de chile.

# %%
import geopandas as gpd

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/COVID-19 Chile (Coronavirus)/Map')

map_data = gpd.read_file('Mapa_Chile_Regiones.geojson')
map_data.head()

mapa = map_data.iloc[:,1:2]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# En este grafico se muestra la concentración de infectados por región.

# %%
fig, ax = plt.subplots(figsize=(15, 15))

ax.set_title('Contagiados por región al '+str(date.today()), 
             pad = 20, 
             fontdict={'fontsize':20, 'color': '#000000'})

ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.2)

casosxregion = df.iloc[:16,2:3]

map_data = map_data.assign(casos=casosxregion)
map_data.plot(column='casos', cmap='OrRd', ax=ax, legend=True, cax=cax, zorder=5)

# %% [markdown]
# En este se muestra los casos totales por número de día.
#
# Lo que hacemos aquí es una regresión polinomial para luego poder predecir los casos totales en un día X.

# %%
dias = np.arange(1,30)
X = dias.reshape(len(dias),1)
y = fq.iloc[:,2:3]

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

poly_regression = PolynomialFeatures(degree=3)
X_poly_regression = poly_regression.fit_transform(X)

lin_regression_2 = LinearRegression()
lin_regression_2.fit(X_poly_regression,y)

X_grid = np.arange(1,30,0.1)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,y,color='red')
plt.plot(X_grid,lin_regression_2.predict(poly_regression.fit_transform(X_grid)),color='blue')
plt.title('N° de casos totales con COVID-19 por día')
plt.xlabel('N° del día')
plt.ylabel('N° del casos totales')
plt.show()

# %% [markdown]
# Aquí hacemos una predicción para los próximos 4 días.

# %%
for i in range(29,32):
  prediccion = int(lin_regression_2.predict(poly_regression.fit_transform([[i]])))
  print('Dia '+str(i)+': '+str(prediccion)+' infectados aprox.')
# Out:
# Dia 29: 2779 infectados aprox.
# Dia 30: 3152 infectados aprox.
# Dia 31: 3558 infectados aprox.
